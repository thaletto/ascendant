# %% [markdown]
# # Getting Started

# %% [markdown]
# ## Installation

# %%
from vedastro import GeoLocation, Time, Calculate, Ayanamsa
# Out:
# VedAstro - Made & Funded by Users - https://vedastro.org/Donate
# c:\Code\Ascendant\agent\.venv\Lib\site-packages\vedastro\update_check.py:2: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %% [markdown]
# ## Config

# %%
birth_place = GeoLocation("Chennai, India", 13.0827, 80.2707)
birth_time = Time("11:55 19/8/2003 +05:21", birth_place)
Calculate.AyanamsaDegree = Ayanamsa.Lahiri

# %% [markdown]
# # Basic Usage

# %%
planet_rashi_signs = Calculate.AllPlanetRasiSigns(birth_time)
planet_rashi_signs
# Out:
# [{'Planet': 'Sun', 'AllPlanetRasiSigns': "Capricorn : 15° 21' 30"},
#  {'Planet': 'Moon', 'AllPlanetRasiSigns': "Virgo : 16° 4' 8"},
#  {'Planet': 'Mars', 'AllPlanetRasiSigns': "Aries : 15° 59' 3"},
#  {'Planet': 'Mercury', 'AllPlanetRasiSigns': "Capricorn : 21° 54' 51"},
#  {'Planet': 'Jupiter', 'AllPlanetRasiSigns': "Libra : 13° 12' 19"},
#  {'Planet': 'Venus', 'AllPlanetRasiSigns': "Pisces : 1° 19' 18"},
#  {'Planet': 'Saturn', 'AllPlanetRasiSigns': "Gemini : 15° 7' 0"},
#  {'Planet': 'Rahu', 'AllPlanetRasiSigns': "Capricorn : 2° 22' 9"},
#  {'Planet': 'Ketu', 'AllPlanetRasiSigns': "Cancer : 2° 22' 9"}]
